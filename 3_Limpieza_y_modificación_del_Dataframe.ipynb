# %% [markdown]
# <a href="https://colab.research.google.com/github/Slrosales/INT_A_LA_ING_DE_SISTEMAS/blob/main/3_Limpieza_y_modificaci%C3%B3n_del_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación e instalación de librerías

# %%
# Importamos la libreria como pd
import pandas as pd

# Importamos la libreria como sns
import seaborn as sns

# Importamos la libreria como plt
import matplotlib.pyplot as plt

# Importamos la libreria como np
import numpy as np

# %% [markdown]
# # Importación del dataset “colombianos detenidos en el exterior”.

# %%
# Leer desde un archivo CSV
df_colombianos_detenidos = pd.read_csv('https://www.datos.gov.co/api/views/e97j-vuf7/rows.csv?accessType=DOWNLOAD')
df_colombianos_detenidos.head(7) # muestrame las primeras 7 filas
# Out:
# <ipython-input-145-1b5737f43e9d>:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_colombianos_detenidos = pd.read_csv('https://www.datos.gov.co/api/views/e97j-vuf7/rows.csv?accessType=DOWNLOAD')
#   FECHA PUBLICACIÓN    PAIS PRISIÓN        CONSULADO        DELITO  \
# 0        2018-09-17         ECUADOR         C. QUITO  NARCOTRÁFICO
# 1        2018-09-17          ITALIA          C. ROMA         OTROS
# 2        2018-09-17  ESTADOS UNIDOS    C. NUEVA YORK     EXTORSIÓN
# 3        2018-09-17          MEXICO        C. MEXICO         OTROS
# 4        2018-09-17           JAPON         C. TOKIO  ROBO / HURTO
# 5        2018-09-17          ITALIA          C. ROMA  ROBO / HURTO
# 6        2018-09-17     DESCONOCIDO  BTA. ASISTENCIA  NARCOTRÁFICO
#
#   EXTRADITADO Y O REPATRIADO SITUACIÓN JURÍDICA     GÉNERO    GRUPO EDAD  \
# 0                DESCONOCIDO          EN JUICIO  MASCULINO   DESCONOCIDO
# ...

# %% [markdown]
# Las columnas del [dataframe](https://www.datos.gov.co/Estad-sticas-Nacionales/Colombianos-detenidos-en-el-exterior/e97j-vuf7) correponden a:
#
#
# *   **FECHA PUBLICACIÓN:** Fecha en que se registran los datos de forma mensual para llevar el histórico de datos
# *   **PAIS PRISIÓN:** País donde se ubica la prisión
# *   **CONSULADO:** Consulado competente para asistir al detenido
# *   **DELITO:** Delito del registro carcelario
# *   **EXTRADITADO Y O REPATRIADO:**	Indica si el detenido ha estado en proceso de extradición o de repatriación
# *   **SITUACIÓN JURÍDICA:** Situación jurídica actual del detenido
# *   **GÉNERO:** Indica el género del detenido
# *   **GRUPO EDAD:** Indica el grupo de edad del detenido
# *   **UBICACIÓN PAÍS:** Geo-localización del país
# *   **CANTIDAD:** Cantidad de detenidos activos
# *   **LATITUD:** Geo-localización del país
# *   **LONGITUD:** Geo-localización del país

# %% [markdown]
# # Observación y descripción de datos

# %%
# Contar el número de filas y columnas en el DataFrame utilizando la función shape
df_colombianos_detenidos.shape
# Out:
# (254137, 12)

# %%
# Estructura y la integridad de tus datos
df_colombianos_detenidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254137 entries, 0 to 254136
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   FECHA PUBLICACIÓN           254137 non-null  object
#  1   PAIS PRISIÓN                254137 non-null  object
#  2   CONSULADO                   254137 non-null  object
#  3   DELITO                      254137 non-null  object
#  4   EXTRADITADO Y O REPATRIADO  254137 non-null  object
#  5   SITUACIÓN JURÍDICA          254137 non-null  object
#  6   GÉNERO                      254137 non-null  object
#  7   GRUPO EDAD                  254137 non-null  object
#  8   UBICACIÓN PAÍS              121827 non-null  object
#  9   CANTIDAD                    254137 non-null  int64
#  10  LATITUD                     237957 non-null  float64
#  11  LONGITUD                    237957 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# ...

# %% [markdown]
# - **RangeIndex:** Indica que hay un total de 254,137 filas en el conjunto de datos.
#
# - **Data columns:** Muestra que el DataFrame tiene un total de 12 columnas.
#
# - **#:** Enumera los nombres de todas las columnas en el DataFrame.
#
# - **Column:** Nombre de las columnas en el DataFrame.
#
# - **Dtype:** Indica los tipos de datos de cada columna.
#
# - **Non-Null Count:** Muestra cuántos valores no nulos hay en cada columna.

# %%
# Resumen estadístico delas variables continuas
df_colombianos_detenidos.describe()
# Out:
#             CANTIDAD        LATITUD       LONGITUD
# count  254137.000000  237957.000000  237957.000000
# mean        4.897681      12.956730     -43.248532
# std        17.392070      22.715127      47.358003
# min         1.000000     -40.900557    -106.346771
# 25%         1.000000       0.000000     -78.183406
# 50%         1.000000       6.423750     -66.589730
# 75%         3.000000      37.090240       0.000000
# max       460.000000      61.924110     174.885971

# %% [markdown]
# 1. **Conteo (count):** Indica la cantidad de valores no nulos en la columna. En este caso, cuántos registros de detenidos tienen un valor en esta columna.
#
# 2. **Media (mean):** Es el promedio aritmético de todos los valores en la columna "CANTIDAD." Representa la tendencia central de los datos. En este caso, cuál es el valor promedio de detenidos activos.
#
# 3. **Desviación estándar (std):** Muestra la dispersión o variabilidad de los valores en la columna. Cuanto mayor sea la desviación estándar, mayor será la dispersión de los datos alrededor de la media.
#
# 4. **Valor mínimo (min):** Indica el valor más bajo en la columna "CANTIDAD."
#
# 5. **Percentiles:** Los percentiles dividen los datos en partes iguales. El percentil 25 (25%) es el valor por debajo del cual cae el 25% de los datos. El percentil 50 (50%) es la mediana, el valor que separa la mitad superior de la mitad inferior de los datos. El percentil 75 (75%) es el valor por debajo del cual cae el 75% de los datos. Basicamente, la distribución los valores por rangos.
#
# 6. **Valor máximo (max):** Indica el valor más alto en la columna "CANTIDAD."

# %%
# Calcular la mediana y la media
mediana = df_colombianos_detenidos['CANTIDAD'].median()
media = df_colombianos_detenidos['CANTIDAD'].mean()

print(f"Media: {media}")
print(f"Mediana: {mediana}")
# Out:
# Media: 4.897681171966302
# Mediana: 1.0

# %% [markdown]
# - Si la media es mucho mayor que la mediana, eso podría indicar que hay valores atípicos (outliers) que están inflando la media.

# %%
# Resumen estadístico de las columnas que contienen datos de tipo objeto
# (columnas que almacenan texto o categorías)
df_colombianos_detenidos.describe(include=object)
# Out:
#        FECHA PUBLICACIÓN PAIS PRISIÓN  CONSULADO        DELITO  \
# count             254137       254137     254137        254137
# unique                41           93        120            40
# top           2022-01-24  DESCONOCIDO  C. MADRID  ROBO / HURTO
# freq               32406       103583      15641         31220
#
#        EXTRADITADO Y O REPATRIADO SITUACIÓN JURÍDICA     GÉNERO GRUPO EDAD  \
# count                      254137             254137     254137     254137
# unique                          4                  8          4          7
# top                   DESCONOCIDO          CONDENADO  MASCULINO     ADULTO
# freq                       239034             108117     199739     112626
#
#        UBICACIÓN PAÍS
# count          121827
# unique             82
# top        (0.0, 0.0)
# freq            27779

# %% [markdown]
# 1. **Conteo (count):** Muestra la cantidad de valores no nulos.
#
# 2. **Valores Únicos (unique):** Muestra la cantidad de valores únicos en cada columna. Representa la diversidad de categorías o textos en cada columna. Cuanto mayor sea el número de valores únicos, más variabilidad hay en los datos.
#
# 3. **Valor Principal (top):** Muestra el valor más común o frecuente en cada columna.
#
# 4. **Frecuencia del Valor Principal (freq):** Es la frecuencia con la que se encuentra el valor más común.

# %% [markdown]
# # Ejemplo de limpieza y modificación del Dataframe

# %% [markdown]
# ## Sobre valores nulos

# %%
# df con solo las filas .any(axis=1) con valores nulos .isnull()
filas_con_nulos = df_colombianos_detenidos[df_colombianos_detenidos.isnull().any(axis=1)]

filas_con_nulos.head()
# Out:
#      FECHA PUBLICACIÓN          PAIS PRISIÓN         CONSULADO  \
# 5283        2022-01-24           DESCONOCIDO         C. PANAMA
# 5952        2022-01-24                  PERU           C. LIMA
# 5990        2022-01-24                CANADA        C. TORONTO
# 6325        2022-01-24  REPUBLICA DOMINICANA  C. SANTO DOMINGO
# 7475        2022-01-24           DESCONOCIDO       C. SAN JOSE
#
#                         DELITO EXTRADITADO Y O REPATRIADO SITUACIÓN JURÍDICA  \
# 5283              ROBO / HURTO                DESCONOCIDO          CONDENADO
# 5952   DESACATO A LA AUTORIDAD                DESCONOCIDO   EN INVESTIGACI�N
# 5990     FALSEDAD EN DOCUMENTO                DESCONOCIDO          EN JUICIO
# 6325                     OTROS                DESCONOCIDO   EN INVESTIGACI�N
# 7475  HOMICIDIO / TENTATIVA DE                DESCONOCIDO          CONDENADO
#
#          GÉNERO    GRUPO EDAD UBICACIÓN PAÍS  CANTIDAD    LATITUD    LONGITUD
# ...

# %% [markdown]
# ### Eliminar valores nulos en todo el DF

# %%
df_colombianos_detenidos_sin_nulos = df_colombianos_detenidos.dropna()
df_colombianos_detenidos_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121827 entries, 0 to 122383
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   FECHA PUBLICACIÓN           121827 non-null  object
#  1   PAIS PRISIÓN                121827 non-null  object
#  2   CONSULADO                   121827 non-null  object
#  3   DELITO                      121827 non-null  object
#  4   EXTRADITADO Y O REPATRIADO  121827 non-null  object
#  5   SITUACIÓN JURÍDICA          121827 non-null  object
#  6   GÉNERO                      121827 non-null  object
#  7   GRUPO EDAD                  121827 non-null  object
#  8   UBICACIÓN PAÍS              121827 non-null  object
#  9   CANTIDAD                    121827 non-null  int64
#  10  LATITUD                     121827 non-null  float64
#  11  LONGITUD                    121827 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# ...

# %% [markdown]
# ### Eliminar valores nulos dada una columna específica

# %%
# Si deseas eliminar filas con valores nulos solo en columnas específicas, puedes hacerlo de la siguiente manera:
df_colombianos_detenidos_sn_ubicacion_pais = df_colombianos_detenidos.dropna(subset=['UBICACIÓN PAÍS'])
df_colombianos_detenidos_sn_ubicacion_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121827 entries, 0 to 122383
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   FECHA PUBLICACIÓN           121827 non-null  object
#  1   PAIS PRISIÓN                121827 non-null  object
#  2   CONSULADO                   121827 non-null  object
#  3   DELITO                      121827 non-null  object
#  4   EXTRADITADO Y O REPATRIADO  121827 non-null  object
#  5   SITUACIÓN JURÍDICA          121827 non-null  object
#  6   GÉNERO                      121827 non-null  object
#  7   GRUPO EDAD                  121827 non-null  object
#  8   UBICACIÓN PAÍS              121827 non-null  object
#  9   CANTIDAD                    121827 non-null  int64
#  10  LATITUD                     121827 non-null  float64
#  11  LONGITUD                    121827 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# ...

# %%
df_colombianos_detenidos_sn_ubicacion_pais[df_colombianos_detenidos.isnull().any(axis=1)].head()
# Out:
# <ipython-input-154-c388134cab71>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_colombianos_detenidos_sn_ubicacion_pais[df_colombianos_detenidos.isnull().any(axis=1)].head()
# Empty DataFrame
# Columns: [FECHA PUBLICACIÓN, PAIS PRISIÓN, CONSULADO, DELITO, EXTRADITADO Y O REPATRIADO, SITUACIÓN JURÍDICA, GÉNERO, GRUPO EDAD, UBICACIÓN PAÍS, CANTIDAD, LATITUD, LONGITUD]
# Index: []

# %% [markdown]
# ### Umbral para eliminar filas que tengan un número mínimo de valores no nulos:

# %%
 # Eliminar filas con al menos 11 valores no nulos
df_colombianos_detenidos_sin_nulos3 = df_colombianos_detenidos.dropna(thresh=11)
df_colombianos_detenidos_sin_nulos3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237957 entries, 0 to 254136
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   FECHA PUBLICACIÓN           237957 non-null  object
#  1   PAIS PRISIÓN                237957 non-null  object
#  2   CONSULADO                   237957 non-null  object
#  3   DELITO                      237957 non-null  object
#  4   EXTRADITADO Y O REPATRIADO  237957 non-null  object
#  5   SITUACIÓN JURÍDICA          237957 non-null  object
#  6   GÉNERO                      237957 non-null  object
#  7   GRUPO EDAD                  237957 non-null  object
#  8   UBICACIÓN PAÍS              121827 non-null  object
#  9   CANTIDAD                    237957 non-null  int64
#  10  LATITUD                     237957 non-null  float64
#  11  LONGITUD                    237957 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# ...

# %%
df_colombianos_detenidos_sin_nulos3[df_colombianos_detenidos.isnull().any(axis=1)].head()
# Out:
# <ipython-input-156-01a2cc194205>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_colombianos_detenidos_sin_nulos3[df_colombianos_detenidos.isnull().any(axis=1)].head()
#      FECHA PUBLICACIÓN          PAIS PRISIÓN         CONSULADO  \
# 5283        2022-01-24           DESCONOCIDO         C. PANAMA
# 5952        2022-01-24                  PERU           C. LIMA
# 5990        2022-01-24                CANADA        C. TORONTO
# 6325        2022-01-24  REPUBLICA DOMINICANA  C. SANTO DOMINGO
# 7475        2022-01-24           DESCONOCIDO       C. SAN JOSE
#
#                         DELITO EXTRADITADO Y O REPATRIADO SITUACIÓN JURÍDICA  \
# 5283              ROBO / HURTO                DESCONOCIDO          CONDENADO
# 5952   DESACATO A LA AUTORIDAD                DESCONOCIDO   EN INVESTIGACI�N
# 5990     FALSEDAD EN DOCUMENTO                DESCONOCIDO          EN JUICIO
# ...

# %% [markdown]
# ## Sobre un dataset específico

# %%
# Gráficas estadisticas

select2 = ['PAIS PRISIÓN', 'CANTIDAD']    # Selección de columnas a trabajar
groups2 = ['PAIS PRISIÓN']     #Selección de columnas que agrupará la información

# Creación de nuevo dataframe y le aplicamos la función sum
pais_mayor_detencion = df_colombianos_detenidos[select2].groupby(by = groups2).sum()


# Ordenar el dataframe descendentemente con respecto a la columna 'CANTIDAD'
pais_mayor_detencion = pais_mayor_detencion.sort_values(by = 'CANTIDAD', ascending = False)

pais_mayor_detencion.reset_index(inplace = True)    #Creación de índices numéricos

pais_mayor_detencion.head(7)    #Se imprime el dataframe para visualizar los datos
# Out:
#      PAIS PRISIÓN  CANTIDAD
# 0     DESCONOCIDO    440465
# 1         ECUADOR    135650
# 2  ESTADOS UNIDOS    134528
# 3       VENEZUELA    117741
# 4          ESPAÑA     93308
# 5          ESPA�A     55088
# 6           CHILE     54836

# %%
# Crear un diccionario de mapeo de correcciones
correcciones = {'ESPA�A': 'ESPAÑA'}

# Aplicar las correcciones a la columna 'Nombre'
pais_mayor_detencion['PAIS PRISIÓN'] = pais_mayor_detencion['PAIS PRISIÓN'].replace(correcciones)

# Usar groupby para agrupar por la columna 'Pais' y luego sumar los valores
pais_mayor_detencion = pais_mayor_detencion.groupby('PAIS PRISIÓN')['CANTIDAD'].sum().reset_index()

# %%
# Ordenar el dataframe descendentemente con respecto a la columna 'CANTIDAD'
pais_mayor_detencion = pais_mayor_detencion.sort_values('CANTIDAD', ascending = False)

pais_mayor_detencion.head(7)    #Se imprime el dataframe para visualizar los datos
# Out:
#       PAIS PRISIÓN  CANTIDAD
# 22     DESCONOCIDO    440465
# 29          ESPAÑA    148396
# 24         ECUADOR    135650
# 30  ESTADOS UNIDOS    134528
# 90       VENEZUELA    117741
# 14           CHILE     54836
# 67          PANAMA     41352

# %%
# Limpieza de datos

# Eliminar filas con un valor específico (en este caso, "DESCONOCIDO" en la columna 'PAIS PRISION')
df_filtrado = pais_mayor_detencion[pais_mayor_detencion['PAIS PRISIÓN'] != 'DESCONOCIDO']
df_filtrado.head(7)
# Out:
#       PAIS PRISIÓN  CANTIDAD
# 29          ESPAÑA    148396
# 24         ECUADOR    135650
# 30  ESTADOS UNIDOS    134528
# 90       VENEZUELA    117741
# 14           CHILE     54836
# 67          PANAMA     41352
# 69            PERU     27351

# %%
# Gráfico de Barras
plt.figure(figsize=(10,5))
sns.barplot(data = df_filtrado.head(5), x = "PAIS PRISIÓN", y = "CANTIDAD");
plt.ylabel('Número de presos');
plt.xlabel('País');

# %%
# Gráfico de barras con más detalles
plt.figure(figsize=(10, 5))  # Aumentar el tamaño de la figura

# Utilizar colores personalizados
colors = sns.color_palette("coolwarm", len(df_filtrado))

# Generar el gráfico de barras con anotaciones
barplot = sns.barplot(data=df_filtrado.head(5), x="PAIS PRISIÓN", y="CANTIDAD", palette=colors)
plt.ylabel('Número de presos', fontsize=12)  # Etiqueta en el eje y
plt.xlabel('País', fontsize=12)  # Etiqueta en el eje x
plt.title('Top 5 de relación del número de presos con el país donde están recluidos', fontsize=14)  # Título del gráfico

# Rotar las etiquetas del eje x para que sean más legibles
plt.xticks(rotation=45, ha="right")



# Agregar etiquetas de datos encima de las barras
"""
for p in barplot.patches: Recorre cada una de las barras en el gráfico de barras (patch)

barplot.annotate(format(p.get_height(), '.0f'), ...: El método annotate agrega una etiqueta de datos a cada barra.

format(p.get_height(), '.0f'): Formatea la altura de la barra como un número entero sin decimales.

(p.get_x() + p.get_width() / 2., p.get_height()): Especifica la posición donde se colocará la etiqueta de datos.

ha='center' y va='baseline': Estos argumentos controlan la alineación horizontal y vertical  de la etiqueta.

xytext=(0, 5): Especifica un desplazamiento (offset) para la posición de la etiqueta.

textcoords='offset points': Indica que el desplazamiento especificado en xytext se interpreta como puntos.
"""
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'baseline',
                     fontsize=10, color='black', xytext = (0, 5),
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# ## Agregar columna al DF

# %% [markdown]
# La función `numpy.where(condción , x, y)` se utiliza para realizar operaciones condicionales en arrays de NumPy y devuelve índices o valores basados en una condición dada.
#
# Parámetros:
#
# 1. **Condición:** Es la condición que se debe evaluar. Para multiples condiciones, se usa & o \|
#
# 2. **x:** Es el valor que se asignará a los elementos que cumplan con la condición.
#
# 3. **y (opcional):** Es el valor que se asignará a los elementos que no cumplan con la condición. Es opcional y se utiliza cuando se va a asignar un valor diferente a los elementos que no cumplen con la condición o por lo contrario, se rellenarán con valores nulos (NaN) por defecto.

# %%
# Creamos una copia del df y a la almacenamos en una nueva variable
df_colombianos_detenidos_alerta = df_colombianos_detenidos.copy()


df_colombianos_detenidos_alerta['ALERTA'] = np.where(
    (df_colombianos_detenidos_alerta['CANTIDAD'] >= 10) & (df_colombianos_detenidos_alerta['SITUACIÓN JURÍDICA'] == 'EN INVESTIGACIÓN'),
    'SI', 'NO'
)

df_colombianos_detenidos_alerta.head()
# Out:
#   FECHA PUBLICACIÓN    PAIS PRISIÓN      CONSULADO        DELITO  \
# 0        2018-09-17         ECUADOR       C. QUITO  NARCOTRÁFICO
# 1        2018-09-17          ITALIA        C. ROMA         OTROS
# 2        2018-09-17  ESTADOS UNIDOS  C. NUEVA YORK     EXTORSIÓN
# 3        2018-09-17          MEXICO      C. MEXICO         OTROS
# 4        2018-09-17           JAPON       C. TOKIO  ROBO / HURTO
#
#   EXTRADITADO Y O REPATRIADO SITUACIÓN JURÍDICA     GÉNERO    GRUPO EDAD  \
# 0                DESCONOCIDO          EN JUICIO  MASCULINO   DESCONOCIDO
# 1                DESCONOCIDO   EN INVESTIGACIÓN  MASCULINO   DESCONOCIDO
# 2                DESCONOCIDO          CONDENADO  MASCULINO        ADULTO
# 3                DESCONOCIDO   EN INVESTIGACIÓN  MASCULINO  ADULTO JOVEN
# 4                DESCONOCIDO          CONDENADO   FEMENINO  ADULTO MAYOR
#
#              UBICACIÓN PAÍS  CANTIDAD    LATITUD    LONGITUD ALERTA
# ...

# %%
df_colombianos_detenidos_alerta_SI = df_colombianos_detenidos_alerta[df_colombianos_detenidos_alerta['ALERTA'] == 'SI'].reset_index(drop=True)

# Eliminación de una columna
# df_colombianos_detenidos_alerta_SI = df_colombianos_detenidos_alerta_SI.drop('index', axis=1)

df_colombianos_detenidos_alerta_SI.head()
# Out:
#   FECHA PUBLICACIÓN    PAIS PRISIÓN             CONSULADO  \
# 0        2018-09-17          ESPAÑA  C. PALMA DE MALLORCA
# 1        2018-09-17  ESTADOS UNIDOS            C. ATLANTA
# 2        2018-09-17       VENEZUELA            C. CARACAS
# 3        2018-09-17         ECUADOR         C. ESMERALDAS
# 4        2018-09-17     DESCONOCIDO              C. QUITO
#
#                                   DELITO EXTRADITADO Y O REPATRIADO  \
# 0  NO REPORTA – CONFIDENCIALIDAD ESTATAL                DESCONOCIDO
# 1                           NARCOTRÁFICO                EXTRADICION
# 2                            DESCONOCIDO                DESCONOCIDO
# 3                           ROBO / HURTO                DESCONOCIDO
# 4                      CRIMEN ORGANIZADO                DESCONOCIDO
#
#   SITUACIÓN JURÍDICA     GÉNERO    GRUPO EDAD           UBICACIÓN PAÍS  \
# 0   EN INVESTIGACIÓN  MASCULINO   DESCONOCIDO    (40.463667, -3.74922)
# ...

# %%
select2 = ['ALERTA', 'CANTIDAD']    # Selección de columnas a trabajar
groups2 = ['ALERTA']     #Selección de columnas que agrupará la información

# Creación de nuevo dataframe y le aplicamos la función sum
df_colombianos_detenidos_alerta = df_colombianos_detenidos_alerta[select2].groupby(by = groups2).sum()


# Ordenar el dataframe descendentemente con respecto a la columna 'CANTIDAD'
df_colombianos_detenidos_alerta = df_colombianos_detenidos_alerta.sort_values(by = 'CANTIDAD', ascending = False)

df_colombianos_detenidos_alerta.reset_index(inplace = True)    #Creación de índices numéricos

df_colombianos_detenidos_alerta.head(7)    #Se imprime el dataframe para visualizar los datos
# Out:
#   ALERTA  CANTIDAD
# 0     NO   1102235
# 1     SI    142447
